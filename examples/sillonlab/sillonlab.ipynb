# %%
import sillonlab as sl
project = sl.load_project()
project.show()
# Out:
# ╭─ sillonlab ─────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  2 runs logged in the project                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# │     Run Name             Timestamp                             Params          Assets            Status         │
# │   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   │
# │     sillonlab            2026-06-12-21:07:06                      2               0              RUNNING        │
# ...

# %%
project.runs().
# Out:
#
#  Run Name           Timestamp                               Params         Results      Tags           Status
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  sillonlab          2026-06-12-21:07:06                       2               0                        RUNNING
#  sillonlab          2026-06-12-21:11:38                       2               0                        RUNNING

# %%
run = project.get("sillonlab")
run.show()
# Out:
# ╭─ sillonlab ─────────────────────────────────────────────────────────────────────╮
# │                                                                                 │
# │  Timestamp  2026-06-12-21:07:06                                                 │
# │  Status      RUNNING                                                            │
# │  Runtime    N/A                                                                 │
# │                                                                                 │
# │                                                                                 │
# │    Parameter    Value                                                           │
# │   ───────────────────────────────────────────────────────────────────────────   │
# │    top_param    [1.0, 1.0909090909090908, 1.1818181818181819, 1.272727272...    │
# │    top_result   [1.0, 1.190082644628099, 1.3966942148760333, 1.6198347107...    │
# ...
