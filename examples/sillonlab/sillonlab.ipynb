# %%
import sillonlab as sl

# %%
project = sl.load_project()

# %%
project.context()
# Out:
# {'mode': 'overview',
#  'runs': [{'id': 'RUNNING',
#    'name': 'sillonlab',
#    'timestamp': '2026-06-12-21:07:06',
#    'param_count': 2,
#    'asset_count': 0,
#    'status': 'RUNNING'},
#   {'id': 'RUNNING',
#    'name': 'sillonlab',
#    'timestamp': '2026-06-12-21:11:38',
#    'param_count': 2,
#    'asset_count': 0,
#    'status': 'RUNNING'}]}

# %%
run = project.get("sillonlab")

# %%
run.parameters.keys()
# Out:
# dict_keys(['top_param', 'top_result'])

# %%
value = run.parameters["top_param"]

# %%
project.query(top_param=lambda v: v!=None)
# Out:
# RunCollection(['sillonlab'])

# %%
run.show()
# Out:
# ╭───────────────────────────────── sillonlab ──────────────────────────────────╮
# │                                                                              │
# │  Timestamp: 2026-06-12-21:07:06                                              │
# │  Status:    RUNNING                                                          │
# │  Runtime:   N/A                                                              │
# │                                                                              │
# │   Parameter   Value                                                          │
# │   top_param   [1.0, 1.0909090909090908, 1.1818181818181819, 1.272727272...   │
# │   top_result  [1.0, 1.190082644628099, 1.3966942148760333, 1.6198347107...   │
# │                                                                              │
# │  Results: none                                                               │
# │  • Top Note                                                                  │
# ...

# %%
project.runs()
# Out:
# RunCollection(['sillonlab', 'sillonlab'])

# %%
print(project.get("sillonlab").load_source())
# Out:
# import sillonpy as sp
# import numpy as np
#
# sp.init("sillonlab")
#
# top_param = np.linspace(1,10,100)
#
# sp.log_param("top_param", top_param)
# top_resut = top_param**2
# sp.log_param("top_result", top_resut)
# sp.add_note("Top Note")
